# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Global CO2 Emissions from Fossil-Fuel Burning,Cement Manufacture, and Gas Flaring: 1751-2013
#
# All emission estimates are expressed in million metric tons of carbon. To
# convert these estimates to units of carbon dioxide (CO2), simply multiply
# these estimates by 3.667.
#
# https://cdiac.ess-dive.lbl.gov/ftp/ndp030/global.1751_2013.ems

# %%
# 1751 - 2013

df = pd.read_csv('global_estimates.csv')

df.head()
# Out:
#    Year  Total  Gas  Liquids  Solids  Production  Flaring  Capita
# 0  1751    3.0  0.0      0.0     3.0         0.0      0.0     NaN
# 1  1752    3.0  0.0      0.0     3.0         0.0      0.0     NaN
# 2  1753    3.0  0.0      0.0     3.0         0.0      0.0     NaN
# 3  1754    3.0  0.0      0.0     3.0         0.0      0.0     NaN
# 4  1755    3.0  0.0      0.0     3.0         0.0      0.0     NaN

# %%
emissions = df.drop(columns=['Capita'])

emissions.head()
# Out:
#    Year  Total  Gas  Liquids  Solids  Production  Flaring
# 0  1751    3.0  0.0      0.0     3.0         0.0      0.0
# 1  1752    3.0  0.0      0.0     3.0         0.0      0.0
# 2  1753    3.0  0.0      0.0     3.0         0.0      0.0
# 3  1754    3.0  0.0      0.0     3.0         0.0      0.0
# 4  1755    3.0  0.0      0.0     3.0         0.0      0.0

# %% [markdown]
# https://data.world/agriculture/nasa-giss-global-temperature/workspace/project-summary?agentid=agriculture&datasetid=nasa-giss-global-temperature

# %%
with open('GLB.Ts+dSST.csv') as f:
    temp = pd.read_csv(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a2d305ba67dd> in <module>
# ----> 1 with open('GLB.Ts+dSST.csv') as f:
#       2     temp = pd.read_csv(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GLB.Ts+dSST.csv'

# %%
temp = temp.drop(columns=['J-D','D-N','DJF','MAM','JJA','SON'])
temp.head()

months = temp.drop(columns=['Year'])

# %%
temp.head()

# %%
years = temp['Year'].tolist()

# %%
col_names = temp.columns.values.tolist()

col_names.remove('Year')

col_names

# %%
fig = go.Figure(data=go.Heatmap(
                   z=months,
                   x=col_names,
                   y=years))
fig.show()

# %% [markdown]
# ## Sentiment

# %%
sentiment = pd.read_csv('climate_sentiment.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-bfa1651a340a> in <module>
# ----> 1 sentiment = pd.read_csv('climate_sentiment.csv')
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %% [markdown]
# ## Water Levels

# %%
sea_levels = pd.read_csv('sea_level.csv')

# %%
sea_levels = sea_levels.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6'])

sea_levels.head()
# Out:
#    Year  Adjusted_Sea_Level
# 0  1880            0.000000
# 1  1881            0.220472
# 2  1882           -0.440945
# 3  1883           -0.232283
# 4  1884            0.590551

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %%
years = sea_levels['Year']
sea = sea_levels['Adjusted_Sea_Level']

# %%
fig = go.Figure(data=go.Heatmap(
                   z=months,
                   x=col_names,
                   y=years))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f1ab8ec47b0b> in <module>
#       1 fig = go.Figure(data=go.Heatmap(
# ----> 2                    z=months,
#       3                    x=col_names,
#       4                    y=years))
#       5 fig.show()
#
# NameError: name 'months' is not defined

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Barpolar(
    r=[77.5, 72.5, 70.0, 45.0, 22.5, 42.5, 40.0, 62.5],
    name='11-14 m/s',
    marker_color='rgb(106,81,163)'
))
fig.add_trace(go.Barpolar(
    r=[57.5, 50.0, 45.0, 35.0, 20.0, 22.5, 37.5, 55.0],
    name='8-11 m/s',
    marker_color='rgb(158,154,200)'
))
fig.add_trace(go.Barpolar(
    r=[40.0, 30.0, 30.0, 35.0, 7.5, 7.5, 32.5, 40.0],
    name='5-8 m/s',
    marker_color='rgb(203,201,226)'
))
fig.add_trace(go.Barpolar(
    r=[20.0, 7.5, 15.0, 22.5, 2.5, 2.5, 12.5, 22.5],
    name='< 5 m/s',
    marker_color='rgb(242,240,247)'
))

fig.update_traces(text=['North', 'N-E', 'East', 'S-E', 'South', 'S-W', 'West', 'N-W'])
fig.update_layout(
    title='Wind Speed Distribution in Laurel, NE',
    font_size=16,
    legend_font_size=16,
    polar_radialaxis_ticksuffix='%',
    polar_angularaxis_rotation=90,

)
fig.show()
# Out:
# <div>
#
#
#             <div id="7b08192d-ed8f-4b2f-850a-b2ed192ed459" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b08192d-ed8f-4b2f-850a-b2ed192ed459")) {
#                     Plotly.newPlot(
#                         '7b08192d-ed8f-4b2f-850a-b2ed192ed459',
# ...

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure()

# %%
years = years.tolist()

years
# Out:
# [1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
# ...

# %%
import plotly.graph_objects as go

fig =go.Figure(go.Sunburst(
 ids=[],
  labels= [
    "North<br>America", "Europe", "Australia", "Football", "Soccer", "Rugby",
    "Football", "Rugby", "American<br>Football", "Football", "Association",
    "Australian<br>Rules", "American<br>Football", "Rugby", "Rugby<br>League",
    "Rugby<br>Union"
  ],
  parents=[
    "", "", "", "North America", "North America", "North America", "Europe",
    "Europe", "Europe","Australia", "Australia - Football", "Australia - Football",
    "Australia - Football", "Australia - Football", "Australia - Rugby",
    "Australia - Rugby"
  ],
))
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))

fig.show()

# %%
for value in sea:
    fig.add_trace(go.Barpolar(
        r=[value],
        name=str(value),
        marker_color='rgb(106,81,163)'
    )) 

fig.update_traces(text=years)

fig.update_layout(
    title='Sea Levels',
    font_size=16,
    legend_font_size=16,
    polar_radialaxis_ticksuffix='%',
    polar_angularaxis_rotation=90,

)

fig.show()
# Out:
# <div>
#
#
#             <div id="72837a1e-1f68-4bc6-9bb6-7dac8b1ac908" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("72837a1e-1f68-4bc6-9bb6-7dac8b1ac908")) {
#                     Plotly.newPlot(
#                         '72837a1e-1f68-4bc6-9bb6-7dac8b1ac908',
# ...
